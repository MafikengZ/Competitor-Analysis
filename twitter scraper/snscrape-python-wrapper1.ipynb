# %% [markdown]
# # Notebook for Scraping Twitter Using snscrape's Python Wrapper

# %%
# Run the pip install command below if you don't already have the library
#! pip install git+https://github.com/JustAnotherArchivist/snscrape.git
#! pip3 install snscrape
# Run the below command if you don't already have Pandas
# !pip install pandas

# %%
# Imports
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# # Query by Username
# The code below will scrape for 100 tweets by a username then provide a CSV file with Pandas

# %%
# Setting variables to be used below
maxTweets = 100

# Creating list to append tweet data to
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:simplilearn since:2022-01-01 until:2022-03-28').get_items()):
    if i>maxTweets:
        break
    tweets_list1.append([ tweet.user.username,tweet.date, tweet.id, tweet.content,tweet.likeCount,
                         tweet.media, tweet.source,tweet.replyCount,tweet.retweetCount])

# %%
# Creating a dataframe from the tweets list above
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Username','Datetime', 'Tweet Id', 'Text','likeCount',
                                                 'Media','Source','ReplyCount','RetweetCount'])

# Display first 5 entries from dataframe
tweets_df1.head()
# Out:
#       Username                  Datetime             Tweet Id  \
# 0  simplilearn 2022-03-27 20:25:47+00:00  1508178489651957766
# 1  simplilearn 2022-03-27 20:23:58+00:00  1508178033865379846
# 2  simplilearn 2022-03-27 06:38:10+00:00  1507970215488991232
# 3  simplilearn 2022-03-27 06:37:03+00:00  1507969934483238919
# 4  simplilearn 2022-03-27 06:19:17+00:00  1507965462453268480
#
#                                                 Text  likeCount Media  \
# 0  @Bhaktipada123 Hi Bhaktipada, this is not the ...          0  None
# 1  @AtulVer17956830 Hi Atul, that's not what we l...          0  None
# 2  @Muhamma67464867 @SimpleLearn Great to see you...          2  None
# 3  @akashmalvi91 Hi Akash! The fee is mentioned o...          1  None
# 4  @Vinodrathod6755 Hi Vinod, that's not what we ...          0  None
#
#                                               Source  ReplyCount  RetweetCount
# 0  <a href="https://app.agorapulse.com" rel="nofo...           0             0
# ...

# %%
#Export dataframe into a CSV
tweets_df1.to_csv('user-tweets.csv', sep=',', index=False)

# %% [markdown]
# # Query by Text Search
# The code below will scrape for 500 tweets between

# %%
# Setting variables to be used below
maxTweets = 500

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('simplilearn').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username,tweet.likeCount,
                         tweet.media, tweet.source,tweet.replyCount,tweet.retweetCount])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username','likeCount',
                                                 'Media','Source','ReplyCount','RetweetCount'])

# Display first 5 entries from dataframe
tweets_df2.head(100)
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-03-28 20:35:58+00:00  1508543441688440833
# 1  2022-03-28 20:30:31+00:00  1508542068896894976
# 2  2022-03-28 18:01:03+00:00  1508504454651428866
# 3  2022-03-28 17:00:18+00:00  1508489166031572992
# 4  2022-03-28 16:28:16+00:00  1508481103753256964
# ..                       ...                  ...
# 95 2022-03-25 20:10:26+00:00  1507449851616792581
# 96 2022-03-25 19:51:11+00:00  1507445007967404033
# 97 2022-03-25 19:15:50+00:00  1507436113610551296
# 98 2022-03-25 18:48:41+00:00  1507429277418999810
# 99 2022-03-25 18:42:58+00:00  1507427839565565955
#
#                                                  Text         Username  \
# 0   @simplilearn Mujhe to kanpur City se hi pyaar ...   3112archiambuj
# 1   Beware of @simplilearn when take admission. Be...     bindazdeepak
# 2   Top 5 Rules For Success By Indra Nooyi | Indra...       DBrainiacs
# 3   Thanks to @simplilearn. Nice short read that m...        quarterli
# ...

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
