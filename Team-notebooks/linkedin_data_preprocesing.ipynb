# %% [markdown]
# ## A SCRIPT TO PERFORM SOME DATA CLEANING AND JOINING OUR CSV FILES INTO A SINGLE FILE

# %% [markdown]
# ### Importing our libraries and modules

# %%
import pandas as pd
import glob
import os

# %% [markdown]
# ### Loading our datasets

# %%
simplilearn = pd.read_csv("simplilearn.csv")
moringa = pd.read_csv("oringa-school.csv")
data_school = pd.read_csv("africa-data-school.csv")
dojo = pd.read_csv("data-science-dojo.csv")
hyperion = pd.read_csv("yperion-development-south-africa.csv")
explore = pd.read_csv("explore-datascience.csv")
udacity = pd.read_csv("dacity.csv")
nyc = pd.read_csv("yc-data-science-academy.csv")
getsmarter = pd.read_csv("etsmarter.csv")

# %% [markdown]
# ### Viewing and cleaning our datasets

# %% [markdown]
# #### 1. Simplilearn

# %%
simplilearn
# Out:
#    our_competitors                 Date_Posted                     Media_Type  \
# 0      Simplilearn  2022-04-21 18:14:29.784992  Other: Poll, Shared Post, etc
# 1      Simplilearn  2022-04-25 14:14:29.784992                          Image
# 2      Simplilearn  2022-04-22 18:14:29.784992  Other: Poll, Shared Post, etc
# 3      Simplilearn  2022-04-21 18:14:29.784992  Other: Poll, Shared Post, etc
# 4      Simplilearn  2022-04-18 18:14:29.784992  Other: Poll, Shared Post, etc
# ..             ...                         ...                            ...
# 74     Simplilearn  2021-09-25 18:14:29.784992  Other: Poll, Shared Post, etc
# 75     Simplilearn  2022-01-25 18:14:29.784992  Other: Poll, Shared Post, etc
# 76     Simplilearn  2021-09-25 18:14:29.784992  Other: Poll, Shared Post, etc
# 77     Simplilearn  2021-09-25 18:14:29.784992  Other: Poll, Shared Post, etc
# 78     Simplilearn  2022-01-25 18:14:29.784992  Other: Poll, Shared Post, etc
#
# ...

# %% [markdown]
# #### 2. Moringa School

# %%
moringa
# Out:
#    our_competitors                 Date_Posted                     Media_Type  \
# 0   Moringa School  2022-04-25 09:22:36.569714                          Image
# 1   Moringa School  2022-04-22 18:22:36.569714                          Image
# 2   Moringa School  2022-04-18 18:22:36.569714                          Image
# 3   Moringa School  2022-04-04 18:22:36.569714                Multiple Images
# 4   Moringa School  2022-04-19 18:22:36.569714  Other: Poll, Shared Post, etc
# ..             ...                         ...                            ...
# 73  Moringa School  2022-04-25 17:52:36.569714                        Article
# 74  Moringa School  2022-01-25 18:22:36.569714                          Image
# 75  Moringa School  2021-10-25 18:22:36.569714                        Article
# 76  Moringa School  2021-10-25 18:22:36.569714                        Article
# 77  Moringa School  2021-10-25 18:22:36.569714                        Article
#
# ...

# %% [markdown]
# The following codeblock is used to create a loop that iterates through our *_"Likes_Counts"_* columns in our moringa dataset and creating a list of the cleaned column and appending it into another empty list.
# After such clean up we transform our cleaned column into a dataframe that we uses to replace the values in out original column with the cleaned values

# %%
likes = []
m_likes = moringa['Likes_Counts']

for m in m_likes:
    likes.append(m[0:2])

# %%
db = pd.DataFrame(likes, columns=["Likes_Counts"])
moringa['Likes_Counts'] = db['Likes_Counts'].values

# %%
moringa
# Out:
#    our_competitors                 Date_Posted                     Media_Type  \
# 0   Moringa School  2022-04-25 09:22:36.569714                          Image
# 1   Moringa School  2022-04-22 18:22:36.569714                          Image
# 2   Moringa School  2022-04-18 18:22:36.569714                          Image
# 3   Moringa School  2022-04-04 18:22:36.569714                Multiple Images
# 4   Moringa School  2022-04-19 18:22:36.569714  Other: Poll, Shared Post, etc
# ..             ...                         ...                            ...
# 73  Moringa School  2022-04-25 17:52:36.569714                        Article
# 74  Moringa School  2022-01-25 18:22:36.569714                          Image
# 75  Moringa School  2021-10-25 18:22:36.569714                        Article
# 76  Moringa School  2021-10-25 18:22:36.569714                        Article
# 77  Moringa School  2021-10-25 18:22:36.569714                        Article
#
# ...

# %%
moringa.to_csv("moringa.csv", index=False)

# %% [markdown]
# #### 3. Africa Data School

# %%
data_school
# Out:
#        our_competitors                 Date_Posted  \
# 0   Africa Data School  2022-03-25 18:20:19.177371
# 1   Africa Data School  2022-04-22 18:20:19.177371
# 2   Africa Data School  2022-04-21 18:20:19.177371
# 3   Africa Data School  2022-04-20 18:20:19.177371
# 4   Africa Data School  2022-04-20 18:20:19.177371
# 5   Africa Data School  2022-04-18 18:20:19.177371
# 6   Africa Data School  2022-04-11 18:20:19.177371
# 7   Africa Data School  2022-04-11 18:20:19.177371
# 8   Africa Data School  2022-04-18 18:20:19.177371
# 9   Africa Data School  2022-04-04 18:20:19.177371
# 10  Africa Data School  2022-04-04 18:20:19.177371
# 11  Africa Data School  2022-04-04 18:20:19.177371
# 12  Africa Data School  2022-04-04 18:20:19.177371
# 13  Africa Data School  2022-03-25 18:20:19.177371
# 14  Africa Data School  2022-03-25 18:20:19.177371
# 15  Africa Data School  2022-03-25 18:20:19.177371
# 16  Africa Data School  2022-03-25 18:20:19.177371
# ...

# %% [markdown]
# #### 4. Data Science Dojo

# %%
dojo
# Out:
#        our_competitors                 Date_Posted  \
# 0    Data Science Dojo  2022-04-23 18:25:11.516221
# 1    Data Science Dojo  2022-04-25 17:55:11.516221
# 2    Data Science Dojo  2022-04-25 17:55:11.516221
# 3    Data Science Dojo  2022-04-25 17:55:11.516221
# 4    Data Science Dojo  2022-04-25 17:55:11.516221
# ..                 ...                         ...
# 162  Data Science Dojo  2022-04-04 18:25:11.516221
# 163  Data Science Dojo  2022-03-25 18:25:11.516221
# 164  Data Science Dojo  2022-04-18 18:25:11.516221
# 165  Data Science Dojo  2022-04-18 18:25:11.516221
# 166  Data Science Dojo  2022-03-25 18:25:11.516221
#
#                         Media_Type  \
# 0    Other: Poll, Shared Post, etc
# 1                            Image
# 2                            Image
# 3                            Image
# 4                            Image
# ..                             ...
# 162                          Image
# 163  Other: Poll, Shared Post, etc
# ...

# %% [markdown]
# #### 5 . Hyperion Development School

# %%
hyperion
# Out:
#     our_competitors                 Date_Posted  \
# 0       HyperionDev  2021-10-25 18:18:06.417603
# 1       HyperionDev  2022-04-20 18:18:06.417603
# 2       HyperionDev  2022-04-20 18:18:06.417603
# 3       HyperionDev  2022-04-18 18:18:06.417603
# 4       HyperionDev  2022-04-18 18:18:06.417603
# ..              ...                         ...
# 191     HyperionDev  2022-04-25 17:48:06.417603
# 192     HyperionDev  2022-04-25 17:48:06.417603
# 193     HyperionDev  2022-04-25 17:48:06.417603
# 194     HyperionDev  2022-04-25 17:48:06.417603
# 195     HyperionDev  2022-04-25 17:48:06.417603
#
#                         Media_Type  \
# 0    Other: Poll, Shared Post, etc
# 1                            Image
# 2                            Image
# 3                            Image
# 4                            Image
# ..                             ...
# 191                          Image
# 192                          Image
# 193                          Image
# ...

# %% [markdown]
# #### 6. Explore Data Science Academy

# %%
explore
# Out:
#                  our_competitors                 Date_Posted  \
# 0   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 1   EXPLORE Data Science Academy  2022-04-25 15:11:16.549970
# 2   EXPLORE Data Science Academy  2022-04-22 18:11:16.549970
# 3   EXPLORE Data Science Academy  2022-04-20 18:11:16.549970
# 4   EXPLORE Data Science Academy  2022-04-21 18:11:16.549970
# 5   EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 6   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 7   EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 8   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 9   EXPLORE Data Science Academy  2022-04-04 18:11:16.549970
# 10  EXPLORE Data Science Academy  2022-03-25 18:11:16.549970
# 11  EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 12  EXPLORE Data Science Academy  2022-04-04 18:11:16.549970
# 13  EXPLORE Data Science Academy  2022-02-25 18:11:16.549970
# ...

# %% [markdown]
# The following codeblock is used to create a loop that iterates through our "Likes_Counts" columns in our moringa dataset and creating a list of the cleaned column and appending it into another empty list. After such clean up we transform our cleaned column into a dataframe that we uses to replace the values in out original column with the cleaned values

# %%
liked = []
m_liked = explore['Likes_Counts']

for e in m_liked:
    liked.append(e[0:2])

# %%
dc = pd.DataFrame(liked, columns=["Likes_Counts"])
explore['Likes_Counts'] = dc['Likes_Counts'].values

# %%
explore
# Out:
#                  our_competitors                 Date_Posted  \
# 0   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 1   EXPLORE Data Science Academy  2022-04-25 15:11:16.549970
# 2   EXPLORE Data Science Academy  2022-04-22 18:11:16.549970
# 3   EXPLORE Data Science Academy  2022-04-20 18:11:16.549970
# 4   EXPLORE Data Science Academy  2022-04-21 18:11:16.549970
# 5   EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 6   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 7   EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 8   EXPLORE Data Science Academy  2022-04-18 18:11:16.549970
# 9   EXPLORE Data Science Academy  2022-04-04 18:11:16.549970
# 10  EXPLORE Data Science Academy  2022-03-25 18:11:16.549970
# 11  EXPLORE Data Science Academy  2022-04-11 18:11:16.549970
# 12  EXPLORE Data Science Academy  2022-04-04 18:11:16.549970
# 13  EXPLORE Data Science Academy  2022-02-25 18:11:16.549970
# ...

# %%
explore.to_csv("edsa.csv", index=False)

# %% [markdown]
# #### 7. Udacity

# %%
udacity
# Out:
#    our_competitors                 Date_Posted                     Media_Type  \
# 0          Udacity  2022-04-23 18:32:40.769565  Other: Poll, Shared Post, etc
# 1          Udacity  2022-04-20 18:32:40.769565  Other: Poll, Shared Post, etc
# 2          Udacity  2022-04-21 18:32:40.769565  Other: Poll, Shared Post, etc
# 3          Udacity  2022-04-11 18:32:40.769565  Other: Poll, Shared Post, etc
# 4          Udacity  2022-04-19 18:32:40.769565                          Image
# ..             ...                         ...                            ...
# 69         Udacity  2022-03-25 18:32:40.769565                        Article
# 70         Udacity  2022-03-25 18:32:40.769565                        Article
# 71         Udacity  2021-11-25 18:32:40.769565  Other: Poll, Shared Post, etc
# 72         Udacity  2022-02-25 18:32:40.769565                        Article
# 73         Udacity  2021-10-25 18:32:40.769565  Other: Poll, Shared Post, etc
#
# ...

# %% [markdown]
# #### 8. NYC

# %%
nyc
# Out:
#               our_competitors                 Date_Posted     Media_Type  \
# 0    NYC Data Science Academy  2022-04-25 17:27:17.337329          Image
# 1    NYC Data Science Academy  2022-04-24 18:27:17.337329          Image
# 2    NYC Data Science Academy  2022-04-18 18:27:17.337329          Image
# 3    NYC Data Science Academy  2022-04-18 18:27:17.337329          Image
# 4    NYC Data Science Academy  2022-04-18 18:27:17.337329          Image
# ..                        ...                         ...            ...
# 130  NYC Data Science Academy  2022-01-25 18:27:17.337329          Image
# 131  NYC Data Science Academy  2021-12-25 18:27:17.337329          Image
# 132  NYC Data Science Academy  2022-04-25 17:57:17.337329  Youtube Video
# 133  NYC Data Science Academy  2021-09-25 18:27:17.337329        Article
# 134  NYC Data Science Academy  2021-12-25 18:27:17.337329          Image
#
#                                           Post_Caption  Likes_Counts  \
# ...

# %% [markdown]
# #### 9. Getsmarter

# %%
getsmarter
# Out:
#    our_competitors                 Date_Posted                     Media_Type  \
# 0       GetSmarter  2022-02-25 18:35:36.579528                          Image
# 1       GetSmarter  2022-04-25 12:35:36.579528                          Image
# 2       GetSmarter  2022-04-21 18:35:36.579528                          Image
# 3       GetSmarter  2022-04-22 18:35:36.579528                          Image
# 4       GetSmarter  2022-04-21 18:35:36.579528                          Image
# ..             ...                         ...                            ...
# 88      GetSmarter  2022-02-25 18:35:36.579528                          Image
# 89      GetSmarter  2021-08-25 18:35:36.579528  Other: Poll, Shared Post, etc
# 90      GetSmarter  2021-08-25 18:35:36.579528  Other: Poll, Shared Post, etc
# 91      GetSmarter  2021-07-25 18:35:36.579528  Other: Poll, Shared Post, etc
# 92      GetSmarter  2021-07-25 18:35:36.579528  Other: Poll, Shared Post, etc
#
# ...

# %% [markdown]
# ## Combining our *_CSV_* files into a single file known as combined_linked_data.csv

# %%
os.chdir("csv")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_linkedin_data.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Viewing our combined converted files

# %%
df = pd.read_csv("combined_linkedin_data.csv")
df
# Out:
#         our_competitors                 Date_Posted Media_Type  \
# 0    Africa Data School  2022-03-25 18:20:19.177371      Image
# 1    Africa Data School  2022-04-22 18:20:19.177371      Image
# 2    Africa Data School  2022-04-21 18:20:19.177371      Image
# 3    Africa Data School  2022-04-20 18:20:19.177371      Image
# 4    Africa Data School  2022-04-20 18:20:19.177371      Image
# ..                  ...                         ...        ...
# 936         HyperionDev  2022-04-25 17:48:06.417603      Image
# 937         HyperionDev  2022-04-25 17:48:06.417603      Image
# 938         HyperionDev  2022-04-25 17:48:06.417603      Image
# 939         HyperionDev  2022-04-25 17:48:06.417603      Image
# 940         HyperionDev  2022-04-25 17:48:06.417603      Image
#
#                                           Post_Caption Likes_Counts  \
# 0    Kickstart your Career in Finance, Healthcare, ...            3
# 1    The Africa Data School community invites you t...            0
# ...
