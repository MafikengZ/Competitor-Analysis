# %% [markdown]
# <a href="https://colab.research.google.com/github/MafikengZ/Competitor-Analysis/blob/main/Facebook_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MafikengZ/Competitor-Analysis/main/Data/facebook/Facebook_GetSmarter.csv')
df.head()
# Out:
#    id                                            message     created_time  \
# 0   2  Our graduates had an average salary increase o...  3/15/2022 23:12
# 1   3  SAVE up to R7500 🔥 Price increase coming soon ...  3/14/2022 16:31
# 2   4  Have you registered for our upcoming Virtual O...  3/12/2022 21:44
# 3   5  Learning to code with HyperionDev was a career...  3/11/2022 18:47
# 4   6  Join our investor webinar, hosted with our CEO...  3/11/2022 16:19
#
#       updated_time  Total_comments  total_reactions  Total_like  Total_love  \
# 0  3/15/2022 23:12               0                1           1           0
# 1  3/14/2022 16:31               0                2           2           0
# 2  3/12/2022 21:44               0                2           2           0
# 3  3/11/2022 18:47               0                5           4           1
# 4  3/11/2022 16:19               0                2           2           0
#
#    Total_haha  Total_wow  Total_sad  Total_angry  Total_likes
# ...

# %%
df_new = df[['message','Total_comments', 'total_reactions']]
df_new.head()
# Out:
#                                              message  Total_comments  \
# 0  Our graduates had an average salary increase o...               0
# 1  SAVE up to R7500 🔥 Price increase coming soon ...               0
# 2  Have you registered for our upcoming Virtual O...               0
# 3  Learning to code with HyperionDev was a career...               0
# 4  Join our investor webinar, hosted with our CEO...               0
#
#    total_reactions
# 0                1
# 1                2
# 2                2
# 3                5
# 4                2

# %%
df_new.plot(kind='scatter', x= 'Total_comments', y = 'total_reactions', color =  'red')
plt.show()

# %%
df_new.to_csv('Facebook_GetSmarter.csv')
